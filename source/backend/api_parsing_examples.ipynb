# %%
import json
import requests
import os
import uuid

# %%
url = 'https://receiptplus.pythonanywhere.com/api/login'
returning_user = {'user_id':'Togekiss',
          'password':'Togekiss'}
response = requests.post(url, json=returning_user)
print('Response code: ' + str(response.status_code))
print(json.dumps(response.json(), indent=4))
print(response.cookies)
session_cookie = response.cookies
# Out:
# Response code: 200
# {
#     "message": "Togekiss logged in successfully."
# }
# <RequestsCookieJar[<Cookie session=.eJwlzjEOwjAMQNG7ZGaIHdeOew52lMQ2VAxILZ0QdycS89OX_ifdYvfjkdb3fvol3TZLayLskCkyj8agS1ciZ5JaW3SRilBcaywcylhY1B0CbSh3YpxdVSM07FlYDEaZ2rgheORCZarlHCWYu4K1jgKOjiS2aCvNRpoj5-H7_-b6uvtzO470_QGoMzGk.ZtJHig.lcF5gX8kv7VCH9pKAdFuLB_gSIU for receiptplus.pythonanywhere.com/>]>

# %%
# url = 'http://127.0.0.1:5000/api/receipts_parsing'
url = 'https://receiptplus.pythonanywhere.com/api/receipts_parsing'
image_path = os.path.join(os.getcwd(), "sample_receipts/QFC_1.jpg")

# Open the image file in binary mode
with open(image_path, 'rb') as image_file:
    # Create a dictionary to store the file data
    files = {
        'receipt_image': (
            image_file
        )
    }
    response = requests.post(url, files=files, cookies = session_cookie)

print('Response code: ' + str(response.status_code))
print(json.dumps(response.json(), indent=4))
# print(response.json().keys())
# Out:
# Response code: 201
# {
#     "location": "2746 NE 45th Street",
#     "purchases": [
#         {
#             "name": "TWIN BROOK MILK",
#             "price": 6.99,
#             "quantity": 1.0
#         },
#         {
#             "name": "BTI DEPOSIT",
#             "price": 2.15,
#             "quantity": 1.0
#         },
#         {
#             "name": "PROG SOUP",
#             "price": 1.49,
#             "quantity": 1.0
#         },
#         {
#             "name": "PROGRESSO SOUP",
#             "price": 1.49,
#             "quantity": 1.0
#         },
#         {
#             "name": "NEXCARE TAPE",
#             "price": 6.49,
#             "quantity": 1.0
#         },
#         {
#             "name": "DAVES KILLER BREADQA",
#             "price": 4.99,
#             "quantity": 1.0
#         },
#         {
#             "name": "GRAPES BLACK",
#             "price": 3.49,
#             "quantity": 2.33
#         },
#         {
#             "name": "GRAPES BLACK",
#             "price": 3.49,
#             "quantity": 1.75
#         },
#         {
#             "name": "EGGPLANT",
#             "price": 2.89,
#             "quantity": 1.0
#         },
#         {
#             "name": "NAVELS CA",
#             "price": 1.99,
#             "quantity": 3.66
#         },
#         {
#             "name": "DRIS STRWBRY",
#             "price": 7.99,
#             "quantity": 1.0
#         },
#         {
#             "name": "GREEN BEANS",
#             "price": 2.99,
#             "quantity": 1.0
#         },
#         {
#             "name": "ROMA TOMATO",
#             "price": 1.99,
#             "quantity": 1.58
#         },
#         {
#             "name": "EGGPLANT",
#             "price": 2.89,
#             "quantity": 1.0
#         },
#         {
#             "name": "BARTLETT ORG QA",
#             "price": 1.99,
#             "quantity": 3.64
#         },
#         {
#             "name": "AVOCADO HASS",
#             "price": 2.99,
#             "quantity": 1.0
#         },
#         {
#             "name": "CALB CRUNCHY LOOPS<+",
#             "price": 1.99,
#             "quantity": 1.0
#         },
#         {
#             "name": "CALB LENTIL SNAPS <+",
#             "price": 1.99,
#             "quantity": 1.0
#         },
#         {
#             "name": "CALB LENTIL SNAPS <t",
#             "price": 1.99,
#             "quantity": 1.0
#         },
#         {
#             "name": "CALB CRUNCHY LOOPS<+",
#             "price": 1.99,
#             "quantity": 1.0
#         },
#         {
#             "name": "TLMK SNCKNG CHEESEQA",
#             "price": 4.99,
#             "quantity": 1.0
#         },
#         {
#             "name": "NTSW TOMATOES",
#             "price": 4.99,
#             "quantity": 1.0
#         },
#         {
#             "name": "RASPBERRIES RED QA",
#             "price": 2.99,
#             "quantity": 1.0
#         },
#         {
#             "name": "BANANAS",
#             "price": 0.69,
#             "quantity": 2.75
#         },
#         {
#             "name": "BANA BAKING",
#             "price": 0.49,
#             "quantity": 3.82
#         },
#         {
#             "name": "SIMPLE TRUTH EGGS",
#             "price": 5.49,
#             "quantity": 1.0
#         },
#         {
#             "name": "CELSSN ICE TEA",
#             "price": 4.99,
#             "quantity": 1.0
#         },
#         {
#             "name": "BROCCOL CROWNS",
#             "price": 2.99,
#             "quantity": 1.28
#         }
#     ],
#     "receipt_date": "10/21/23",
#     "store": "jobs.qfc.com",
#     "total": 119.31
# }

# %%
# url = 'http://127.0.0.1:5000/api/receipts_parsing'
url = 'https://receiptplus.pythonanywhere.com/api/receipts_parsing'
image_path = os.path.join(os.getcwd(), "sample_receipts/QFC_2.jpg")

# Open the image file in binary mode
with open(image_path, 'rb') as image_file:
    # Create a dictionary to store the file data
    files = {
        'receipt_image': (
            image_file
        )
    }
    response = requests.post(url, files=files, cookies = session_cookie)

print('Response code: ' + str(response.status_code))
print(json.dumps(response.json(), indent=4))
# print(response.json().keys())
# Out:
# Response code: 201
# {
#     "location": "2746 NE 45th Street",
#     "purchases": [
#         {
#             "name": "WT DOLE BANANAS",
#             "price": 0.69,
#             "quantity": 3.01
#         }
#     ],
#     "receipt_date": "02/24/24",
#     "store": "QFC",
#     "total": 2.08
# }

# %%
# url = 'http://127.0.0.1:5000/api/receipts_parsing'
url = 'https://receiptplus.pythonanywhere.com/api/receipts_parsing'
image_path = os.path.join(os.getcwd(), "sample_receipts/TJ_1.jpg")

# Open the image file in binary mode
with open(image_path, 'rb') as image_file:
    # Create a dictionary to store the file data
    files = {
        'receipt_image': (
            image_file
        )
    }
    response = requests.post(url, files=files, cookies = session_cookie)

print('Response code: ' + str(response.status_code))
print(json.dumps(response.json(), indent=4))
# print(response.json().keys())
# Out:
# Response code: 201
# {
#     "location": "4555 Roosevelt Way NE\nSeattle, WA 98105",
#     "purchases": [
#         {
#             "name": "MILK ORGANIC GALLON WHOL",
#             "price": 6.49,
#             "quantity": 1.0
#         },
#         {
#             "name": "CARROTS CUT & PEELED 1.5",
#             "price": 1.69,
#             "quantity": 1.0
#         },
#         {
#             "name": "A-MANDARIN JOSIE'S 5 LB",
#             "price": 6.99,
#             "quantity": 1.0
#         },
#         {
#             "name": "APPLE EACH PINK LADY",
#             "price": 0.69,
#             "quantity": 3.0
#         },
#         {
#             "name": "A-APPLES FUJI EACH",
#             "price": 0.69,
#             "quantity": 2.0
#         },
#         {
#             "name": "BANANA EACH",
#             "price": 0.23,
#             "quantity": 9.0
#         },
#         {
#             "name": "ROLLS CIABATTA EVERYTHIN",
#             "price": 2.49,
#             "quantity": 1.0
#         },
#         {
#             "name": "ORG ELOTE CORN CHIPS",
#             "price": 2.49,
#             "quantity": 1.0
#         },
#         {
#             "name": "T BAG FEE",
#             "price": 0.08,
#             "quantity": 2.0
#         }
#     ],
#     "receipt_date": "04-30-24",
#     "store": "TRADER JOE'S",
#     "total": 32.3
# }

# %%
# url = 'http://127.0.0.1:5000/api/receipts_parsing'
url = 'https://receiptplus.pythonanywhere.com/api/receipts_parsing'
image_path = os.path.join(os.getcwd(), "sample_receipts/TJ_2.jpg")

# Open the image file in binary mode
with open(image_path, 'rb') as image_file:
    # Create a dictionary to store the file data
    files = {
        'receipt_image': (
            image_file
        )
    }
    response = requests.post(url, files=files, cookies = session_cookie)

print('Response code: ' + str(response.status_code))
print(json.dumps(response.json(), indent=4))
# print(response.json().keys())
# Out:
# Response code: 201
# {
#     "location": "4555 Roosevelt Way NE\nSeattle, WA 98105",
#     "purchases": [
#         {
#             "name": "BLUEBERRIES 110Z",
#             "price": 3.99,
#             "quantity": 1.0
#         },
#         {
#             "name": "PEAR EACH BARTLETT",
#             "price": 0.79,
#             "quantity": 4.0
#         }
#     ],
#     "receipt_date": "03-29-24",
#     "store": "TRADER JOE'S",
#     "total": 15.13
# }

# %%
# url = 'http://127.0.0.1:5000/api/receipts_parsing'
url = 'https://receiptplus.pythonanywhere.com/api/receipts_parsing'
image_path = os.path.join(os.getcwd(), "sample_receipts/TJ_3.jpg")

# Open the image file in binary mode
with open(image_path, 'rb') as image_file:
    # Create a dictionary to store the file data
    files = {
        'receipt_image': (
            image_file
        )
    }
    response = requests.post(url, files=files, cookies = session_cookie)

print('Response code: ' + str(response.status_code))
print(json.dumps(response.json(), indent=4))
# print(response.json().keys())
# Out:
# Response code: 201
# {
#     "location": "4555 Roosevelt Way NE\nSeattle, WA 98105",
#     "purchases": [
#         {
#             "name": "FOCACCIA TOMATO RED ONIO",
#             "price": 2.99,
#             "quantity": 1.0
#         },
#         {
#             "name": "TOFU FIRM ORGANIC 14 OZ",
#             "price": 1.79,
#             "quantity": 2.0
#         },
#         {
#             "name": "EGGS LARGE ORGANIC BROW",
#             "price": 3.99,
#             "quantity": 1.0
#         },
#         {
#             "name": "TUSCAN PANE",
#             "price": 3.49,
#             "quantity": 1.0
#         },
#         {
#             "name": "FRESH BRUSCHETTA",
#             "price": 2.99,
#             "quantity": 1.0
#         }
#     ],
#     "receipt_date": "03-29-24",
#     "store": "TRADER JOE'S",
#     "total": 17.04
# }

# %%
# url = 'http://127.0.0.1:5000/api/receipts_parsing'
url = 'https://receiptplus.pythonanywhere.com/api/receipts_parsing'
image_path = os.path.join(os.getcwd(), "sample_receipts/TJ_4.jpg")

# Open the image file in binary mode
with open(image_path, 'rb') as image_file:
    # Create a dictionary to store the file data
    files = {
        'receipt_image': (
            image_file
        )
    }
    response = requests.post(url, files=files, cookies = session_cookie)

print('Response code: ' + str(response.status_code))
print(json.dumps(response.json(), indent=4))
# print(response.json().keys())
# Out:
# Response code: 201
# {
#     "location": "4555 Roosevelt Way NE\nSeattle, WA 98105",
#     "purchases": [
#         {
#             "name": "EGGS LARGE ORGANIC BROW",
#             "price": 3.99,
#             "quantity": 1.0
#         }
#     ],
#     "receipt_date": "03-31-24",
#     "store": "TRADER JOE'S",
#     "total": 3.99
# }

# %%
# url = 'http://127.0.0.1:5000/api/receipts_parsing'
url = 'https://receiptplus.pythonanywhere.com/api/receipts_parsing'
image_path = os.path.join(os.getcwd(), "sample_receipts/HMART_1.jpg")

# Open the image file in binary mode
with open(image_path, 'rb') as image_file:
    # Create a dictionary to store the file data
    files = {
        'receipt_image': (
            image_file
        )
    }
    response = requests.post(url, files=files, cookies = session_cookie)

print('Response code: ' + str(response.status_code))
print(json.dumps(response.json(), indent=4))
# print(response.json().keys())
# Out:
# Response code: 201
# {
#     "location": "4216 University Way NE, Seattle, WA, 98105",
#     "purchases": [
#         {
#             "name": "NS)ONION RINGS",
#             "price": 6.49,
#             "quantity": 1.0
#         }
#     ],
#     "receipt_date": "Mar 31, 2024",
#     "store": "HMART",
#     "total": 6.49
# }

# %%
# url = 'http://127.0.0.1:5000/api/receipts_parsing'
url = 'https://receiptplus.pythonanywhere.com/api/receipts_parsing'
image_path = os.path.join(os.getcwd(), "sample_receipts/HMART_2.jpg")

# Open the image file in binary mode
with open(image_path, 'rb') as image_file:
    # Create a dictionary to store the file data
    files = {
        'receipt_image': (
            image_file
        )
    }
    response = requests.post(url, files=files, cookies = session_cookie)

print('Response code: ' + str(response.status_code))
print(json.dumps(response.json(), indent=4))
# print(response.json().keys())
# Out:
# Response code: 201
# {
#     "location": "4216\nUniversity Way NE, Seattle, WA, 98105",
#     "purchases": [
#         {
#             "name": "SEOUL) EGG TART",
#             "price": 2.29,
#             "quantity": 1.0
#         },
#         {
#             "name": null,
#             "price": 4.99,
#             "quantity": 1.0
#         },
#         {
#             "name": "NISHIKI) WHITE RICE 15LB\nLADI) \u244901 15LB 15LB",
#             "price": 24.49,
#             "quantity": 1.0
#         }
#     ],
#     "receipt_date": "Apr 01, 2024",
#     "store": "(3)",
#     "total": 31.77
# }

# %%
# url = 'http://127.0.0.1:5000/api/receipts_parsing'
url = 'https://receiptplus.pythonanywhere.com/api/receipts_parsing'
image_path = os.path.join(os.getcwd(), "sample_receipts/HMART_3.jpg")

# Open the image file in binary mode
with open(image_path, 'rb') as image_file:
    # Create a dictionary to store the file data
    files = {
        'receipt_image': (
            image_file
        )
    }
    response = requests.post(url, files=files, cookies = session_cookie)

print('Response code: ' + str(response.status_code))
print(json.dumps(response.json(), indent=4))
# print(response.json().keys())
# Out:
# Response code: 201
# {
#     "location": "4216 University Way NE, Seattle, WA, 98105",
#     "purchases": [
#         {
#             "name": "DARIGOLD)WHOLE MILK",
#             "price": 4.99,
#             "quantity": 1.0
#         },
#         {
#             "name": "SM)COCOA-DARK CHOCO\nI 7.68OZ",
#             "price": 4.49,
#             "quantity": 1.0
#         },
#         {
#             "name": "SM)COCOA-DARK CHOCO\nT) 7.68OZ",
#             "price": 4.49,
#             "quantity": 1.0
#         },
#         {
#             "name": "GM) BLACK SESAME CEREAL\nGM) 420G",
#             "price": 7.49,
#             "quantity": 1.0
#         },
#         {
#             "name": "GREEN ONION (BUN)\nIII- MEX PK",
#             "price": 1.49,
#             "quantity": 1.0
#         },
#         {
#             "name": "YELLOW BANANA (LB)\nHILL- GT OLB",
#             "price": 1.49,
#             "quantity": 3.34
#         },
#         {
#             "name": "YELLOW BANANA (LB)\nHLL- GT OLB",
#             "price": 1.49,
#             "quantity": 2.49
#         },
#         {
#             "name": "REUSABLE BAG",
#             "price": 0.08,
#             "quantity": 1.0
#         }
#     ],
#     "receipt_date": "Feb 12, 2024",
#     "store": "HMART",
#     "total": 31.73
# }
